# %%
import pandas as pd
import _csv

data_2015 = pd.read_csv('2015.csv')
data_2016 = pd.read_csv('2016.csv')

print("2015 World Happiness Datas","\n")

data_2015.describe()
# Out:
# 2015 World Happiness Datas
#        Happiness Rank  Happiness Score  Standard Error  \
# count      157.000000       157.000000      157.000000
# mean        78.993631         5.391892        0.047761
# std         45.465611         1.130460        0.017130
# min          1.000000         2.905000        0.018480
# 25%         40.000000         4.550000        0.037260
# 50%         79.000000         5.253000        0.043940
# 75%        118.000000         6.269000        0.052240
# max        157.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                157.000000  157.000000                157.000000
# mean                   0.850197    0.996467                  0.632462
# std                    0.401157    0.264552                  0.246307
# min                    0.000000    0.000000                  0.000000
# 25%                    0.546490    0.860400                  0.440550
# ...

# %%
data_2015.head()
#or
#df_2015.iloc[0:4]
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
data_2016.describe()
# Out:
#        Happiness Rank  Happiness Score  Lower Confidence Interval  \
# count      157.000000       157.000000                 157.000000
# mean        78.980892         5.382185                   5.282395
# std         45.466030         1.141674                   1.148043
# min          1.000000         2.905000                   2.732000
# 25%         40.000000         4.404000                   4.327000
# 50%         79.000000         5.314000                   5.237000
# 75%        118.000000         6.269000                   6.154000
# max        157.000000         7.526000                   7.460000
#
#        Upper Confidence Interval  Economy (GDP per Capita)      Family  \
# count                 157.000000                157.000000  157.000000
# mean                    5.481975                  0.953880    0.793621
# std                     1.136493                  0.412595    0.266706
# min                     3.078000                  0.000000    0.000000
# ...

# %%
data_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
data_2015_columns_name = data_2015.columns
data_2016_columns_name = data_2016.columns

print("columns that not be included in the comparison")
print("for 2015 :")
print(list(set(data_2015_columns_name) - set(data_2016_columns_name)))

print("for 2016 :")
print(list(set(data_2016_columns_name) - set(data_2015_columns_name)))

df_2015 = data_2015.drop("Standard Error" , axis=1)
df_2016 = data_2016.drop(data_2016.columns[[4,5]] , axis = 1)

if(set(df_2015) - set(df_2016) == set()):
    if(set(df_2016) - set(df_2015) == set()):
        print("Succesfully deleted.Dataset's columns are equal.")
# Out:
# columns that not be included in the comparison
# for 2015 :
# ['Standard Error']
# for 2016 :
# ['Upper Confidence Interval', 'Lower Confidence Interval']
# Succesfully deleted.Dataset's columns are equal.

# %%
import numpy as np
print("2015 Happiest Country")

happiest15 = df_2015.iloc[:,[0,2]]

x = happiest15[(happiest15['Happiness Rank']==1)]
#country name :

x.iloc[:,0]
df_2015.drop([157],inplace=False,axis=0)
# Out:
# 2015 Happiest Country
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\bahar\Desktop\data mining\world_happy_project\compare.ipynb Hücre 6 in <cell line: 10>()
#       <a href='vscode-notebook-cell:/c%3A/Users/bahar/Desktop/data%20mining/world_happy_project/compare.ipynb#ch0000005?line=6'>7</a> #country name :
#       <a href='vscode-notebook-cell:/c%3A/Users/bahar/Desktop/data%20mining/world_happy_project/compare.ipynb#ch0000005?line=8'>9</a> x.iloc[:,0]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/bahar/Desktop/data%20mining/world_happy_project/compare.ipynb#ch0000005?line=9'>10</a> df_2015.drop([157],inplace=False,axis=0)
#
# File c:\Users\bahar\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
# ...

# %%
print("2016 Happiest Country")
happiest16 = df_2016.iloc[:,[0,2]]

y = happiest16[(happiest16['Happiness Rank']==1)]
y.iloc[:,0]
# Out:
# 2016 Happiest Country
# 0    Denmark
# Name: Country, dtype: object

# %%
import csv

dict_from_csv = {}

with open('2015.csv', mode='r') as inp:
    reader = csv.reader(inp)
    dict_from_csv = {rows[0]:rows[3] for rows in reader}

print(dict_from_csv)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\bahar\Desktop\data mining\world_happy_project\compare.ipynb Hücre 8 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/bahar/Desktop/data%20mining/world_happy_project/compare.ipynb#ch0000007?line=4'>5</a> with open('2015.csv', mode='r') as inp:
#       <a href='vscode-notebook-cell:/c%3A/Users/bahar/Desktop/data%20mining/world_happy_project/compare.ipynb#ch0000007?line=5'>6</a>     reader = csv.reader(inp)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/bahar/Desktop/data%20mining/world_happy_project/compare.ipynb#ch0000007?line=6'>7</a>     dict_from_csv = {rows[0]:rows[3] for rows in reader}
#       <a href='vscode-notebook-cell:/c%3A/Users/bahar/Desktop/data%20mining/world_happy_project/compare.ipynb#ch0000007?line=8'>9</a> print(dict_from_csv)
#
# ...

# %%
import csv

dict_from_csv2 = {}

with open('2016.csv', mode='r') as inp:
    reader = csv.reader(inp)
    dict_from_csv2 = {rows[0]:rows[3] for rows in reader}

print(dict_from_csv2)
# Out:
# {'Country': 'Happiness Score', 'Denmark': '7.526', 'Switzerland': '7.509', 'Iceland': '7.501', 'Norway': '7.498', 'Finland': '7.413', 'Canada': '7.404', 'Netherlands': '7.339', 'New Zealand': '7.334', 'Australia': '7.313', 'Sweden': '7.291', 'Israel': '7.267', 'Austria': '7.119', 'United States': '7.104', 'Costa Rica': '7.087', 'Puerto Rico': '7.039', 'Germany': '6.994', 'Brazil': '6.952', 'Belgium': '6.929', 'Ireland': '6.907', 'Luxembourg': '6.871', 'Mexico': '6.778', 'Singapore': '6.739', 'United Kingdom': '6.725', 'Chile': '6.705', 'Panama': '6.701', 'Argentina': '6.65', 'Czech Republic': '6.596', 'United Arab Emirates': '6.573', 'Uruguay': '6.545', 'Malta': '6.488', 'Colombia': '6.481', 'France': '6.478', 'Thailand': '6.474', 'Saudi Arabia': '6.379', 'Taiwan': '6.379', 'Qatar': '6.375', 'Spain': '6.361', 'Algeria': '6.355', 'Guatemala': '6.324', 'Suriname': '6.269', 'Kuwait': '6.239', 'Bahrain': '6.218', 'Trinidad and Tobago': '6.168', 'Venezuela': '6.084', 'Slovakia': '6.078', 
# ...

# %% [markdown]
# import csv
#
# with open('test7.csv', 'w') as f:
#     for key in dict_from_csv.keys():
#         f.write("%s, %s\n" % (key, dict_from_csv[key]))

# %%
df_2015.drop([157],inplace=True,axis = 0)

# %% [markdown]
# csv_input = pd.read_csv('test7.csv')
# csv_input['Happiness Score16'] = dict_from_csv2.values()
# csv_input.to_csv('test7.csv', index=False)

# %%
import matplotlib.pyplot as plt

first10 = df_2015.iloc[0:11,:]
firs102 = df_2016.iloc[0:11,:]

scores_no = first10["Happiness Score"]
scores_no2 = firs102["Happiness Score"]


labels = first10["Country"]

array1 = []
array2 = []
array3 = []
for score in scores_no:
    array1.append(score)


for score2 in scores_no2:
    array2.append(score2)

for country in labels:
    array3.append(country)

df = pd.DataFrame({'HS15': array1,
                   'HS16': array2}, index=array3)
ax = df.plot.bar(rot=0)

# %%
df_2015.iloc[0:11,:]
# Out:
#         Country                           Region  Happiness Rank  \
# 1       Iceland                   Western Europe               2
# 2       Denmark                   Western Europe               3
# 3        Norway                   Western Europe               4
# 4        Canada                    North America               5
# 5       Finland                   Western Europe               6
# 6   Netherlands                   Western Europe               7
# 7        Sweden                   Western Europe               8
# 8   New Zealand        Australia and New Zealand               9
# 9     Australia        Australia and New Zealand              10
# 10       Israel  Middle East and Northern Africa              11
#
#     Happiness Score  Economy (GDP per Capita)   Family  \
# 1             7.561                   1.30232  1.40223
# 2             7.527                   1.32548  1.36058
# 3             7.522                   1.45900  1.33095
# ...

# %%
df_2015['Region'].value_counts().plot.pie()
import matplotlib.pyplot as plt
plt.gca().set_aspect('equal')

# %%
from numpy import size


region_data = df_2015['Region'].value_counts()

region = df_2015['Region']
plt.pie(region_data, autopct='%1.1f%%', shadow=True, startangle=10)
# Out:
# ([<matplotlib.patches.Wedge at 0x2a8d1586f20>,
# ...
#  [Text(0.6354337774973708, 0.897899724031265, ''),
#   Text(-0.7456251055858901, 0.8087293749580451, ''),
#   Text(-1.0792497054530314, -0.21265011939696948, ''),
#   Text(-0.5425702782958037, -0.9568790378673859, ''),
#   Text(0.32990165634114027, -1.0493640441445344, ''),
#   Text(0.8512320321926341, -0.696709428218966, ''),
#   Text(1.0272449510537007, -0.39340540226931314, ''),
#   Text(1.09387140521645, -0.11595408078109727, ''),
#   Text(1.098368435096872, 0.059889738543829396, ''),
#   Text(1.0900634749773914, 0.1475182040299232, '')],
#  [Text(0.34660024227129316, 0.4897634858352354, '24.8%'),
#   Text(-0.40670460304684913, 0.4411251136134791, '18.5%'),
#   Text(-0.5886816575198353, -0.11599097421652879, '14.0%'),
#   Text(-0.2959474245249838, -0.5219340206549377, '13.4%'),
#   Text(0.17994635800425832, -0.5723803877152005, '12.7%'),
#   Text(0.46430838119598217, -0.38002332448307236, '5.7%'),
# ...

# %%
values = list(dict_from_csv2.values())
courses = list(dict_from_csv2.keys())



fig = plt.figure(figsize=(20, 20))
# creating the bar plot
plt.barh(courses, values, color='maroon')
  
plt.xlabel("Happiness Score")
plt.ylabel("Country")


plt.show()

# %%
group_data = list(dict_from_csv2.values())
group_names = list(dict_from_csv2.keys())

fig, ax = plt.subplots()
plt.figure(figsize=(20,20))

ax.barh(group_names, group_data)

ax.set_xlabel('Happiness Score')
# Out:
# Text(0.5, 0, 'Happiness Score')
